# %%
import pandas as pd

hpo_table = pd.read_csv("gru_hpo_search_spaces.csv")

hpo_table
# Out:
#                         hpo_run    gru_dropout     gru_hidden gru_layers  \
# 0  gru_ablation_revin_scheduler            NaN            NaN        NaN
# 1             gru_small_grid_v1  0.1, 0.2, 0.3   128, 192, 96    1, 2, 3
# 2             gru_small_grid_v2            0.2  192, 224, 256    2, 3, 4
# 3             gru_small_grid_v3            0.2       160, 192       4, 5
# 4           gru_small_refine_v4            0.2  160, 176, 192          4
#
#                                lr lr_scheduler.enabled    use_revin
# 0                             NaN          False, True  False, True
# 1           0.0001, 0.0003, 0.001                  NaN          NaN
# 2  0.0002, 0.0003, 0.0004, 0.0005                  NaN          NaN
# 3         0.0003, 0.00035, 0.0004                  NaN          NaN
# 4       0.00035, 0.000375, 0.0004                  NaN          NaN
